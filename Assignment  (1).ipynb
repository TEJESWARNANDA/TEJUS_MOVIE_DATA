# %%
# Supress Warnings

#Use this cell to ignore the warnings.

#[Your Code]

# %%
# Import the numpy and pandas packages

#[Your Code]

# %% [markdown]
# ## Task 1: Reading and Inspection
#
# -  ### Subtask 1.1: Import and read
#
# Import and read the movie data. Store it in a variable called `movies`.

# %%
#Making Sure that the csv file belong to the same directory as this file. And then using head command to read few rows.
#Else complete path of the directory can be used to read the file.
#read_csv is used to read the deimited file.

import numpy as np
import pandas as pd
movies=pd.read_csv('MovieData.csv')

# %% [markdown]
# -  ### Subtask 1.2: Inspect the dataframe
#
# Inspect the dataframe's columns, shapes, variable types etc.

# %%
# Write your code for inspection here
movies.head()

#Find the the initial rows count for future references.
# Out:
#    color      director_name  num_critic_for_reviews  duration  \
# 0  Color      James Cameron                   723.0     178.0
# 1  Color     Gore Verbinski                   302.0     169.0
# 2  Color         Sam Mendes                   602.0     148.0
# 3  Color  Christopher Nolan                   813.0     164.0
# 4    NaN        Doug Walker                     NaN       NaN
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                   855.0  Joel David Moore
# 1                    563.0                  1000.0     Orlando Bloom
# 2                      0.0                   161.0      Rory Kinnear
# 3                  22000.0                 23000.0    Christian Bale
# 4                    131.0                     NaN        Rob Walker
#
#    actor_1_facebook_likes        gross                           genres  \
# 0                  1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi
# 1                 40000.0  309404152.0         Action|Adventure|Fantasy
# 2                 11000.0  200074175.0        Action|Adventure|Thriller
# 3                 27000.0  448130642.0                  Action|Thriller
# 4                   131.0          NaN                      Documentary
#
#           ...          num_user_for_reviews language  country  content_rating  \
# 0         ...                        3054.0  English      USA           PG-13
# 1         ...                        1238.0  English      USA           PG-13
# 2         ...                         994.0  English       UK           PG-13
# 3         ...                        2701.0  English      USA           PG-13
# 4         ...                           NaN      NaN      NaN             NaN
#
#         budget  title_year actor_2_facebook_likes imdb_score  aspect_ratio  \
# 0  237000000.0      2009.0                  936.0        7.9          1.78
# 1  300000000.0      2007.0                 5000.0        7.1          2.35
# 2  245000000.0      2015.0                  393.0        6.8          2.35
# 3  250000000.0      2012.0                23000.0        8.5          2.35
# 4          NaN         NaN                   12.0        7.1           NaN
#
#   movie_facebook_likes
# 0                33000
# 1                    0
# 2                85000
# 3               164000
# 4                    0
#
# [5 rows x 28 columns]

# %% [markdown]
# ## Task 2: Cleaning the Data
#
# -  ### Subtask 2.1: Inspect Null values
#
# Find out the number of Null values in all the columns and rows. Also, find the percentage of Null values in each column. Round off the percentages upto two decimal places.

# %%
# Write your code for column-wise null count here

#Hint : isnull returns boolean True/False for column value to be null or not, sum will add int count. 
movies.isna().sum()
# Out:
# color                         19
# director_name                104
# num_critic_for_reviews        50
# duration                      15
# director_facebook_likes      104
# actor_3_facebook_likes        23
# actor_2_name                  13
# actor_1_facebook_likes         7
# gross                        884
# genres                         0
# actor_1_name                   7
# movie_title                    0
# num_voted_users                0
# cast_total_facebook_likes      0
# actor_3_name                  23
# facenumber_in_poster          13
# plot_keywords                153
# movie_imdb_link                0
# num_user_for_reviews          21
# language                      12
# country                        5
# content_rating               303
# budget                       492
# title_year                   108
# actor_2_facebook_likes        13
# imdb_score                     0
# aspect_ratio                 329
# movie_facebook_likes           0
# dtype: int64

# %%
# Write your code for row-wise null count here

#Sum of ISNull along axis 1 will give the null count row-wise. 
movies.loc[[0]].isna().sum()
movies.loc[[1]].isna().sum()
movies.loc[[2]].isna().sum()
movies.loc[[3]].isna().sum()
movies.loc[[4]].isna().sum().sum() #The first sum is for count of the null values and the second one if for adding all the values
# Out:
# 14

# %%
# Write your code for column-wise null percentages here

# Sum of all nulls of column/Total count converted to percentage and rounded to 2 digits.
null_percent=movies.isna().sum().sum()*100/len(movies)
print(np.round(null_percent,2))
# Out:
# 36.31

# %% [markdown]
# -  ### Subtask 2.2: Drop unecessary columns
#
# For this assignment, you will mostly be analyzing the movies with respect to the ratings, gross collection, popularity of movies, etc. So many of the columns in this dataframe are not required. So it is advised to drop the following columns.
# -  color
# -  director_facebook_likes
# -  actor_1_facebook_likes
# -  actor_2_facebook_likes
# -  actor_3_facebook_likes
# -  actor_2_name
# -  cast_total_facebook_likes
# -  actor_3_name
# -  duration
# -  facenumber_in_poster
# -  content_rating
# -  country
# -  movie_imdb_link
# -  aspect_ratio
# -  plot_keywords

# %%
# Write your code for dropping the columns here. It is advised to keep inspecting the dataframe after each set of operations 

#Dropping the columns which are not required.Written in Multiple lines for readbility.


del(movies['director_facebook_likes'])
del(movies['director_facebook_likes'])
del(movies['actor_1_facebook_likes'])
del(movies['actor_2_facebook_likes'])
del(movies['actor_3_facebook_likes'])
del(movies['actor_2_name'])
del(movies['cast_total_facebook_likes'])
del(movies['actor_3_name'])
del(movies['duration'])
del(movies['facenumber_in_poster'])
del(movies['content_rating'])
del(movies['country'])
del(movies['movie_imdb_link'])
del(movies['aspect_ratio'])
del(movies['plot_keywords'])
movies.head()
# Out:
#        director_name  num_critic_for_reviews        gross  \
# 0      James Cameron                   723.0  760505847.0
# 1     Gore Verbinski                   302.0  309404152.0
# 2         Sam Mendes                   602.0  200074175.0
# 3  Christopher Nolan                   813.0  448130642.0
# 4        Doug Walker                     NaN          NaN
#
#                             genres     actor_1_name  \
# 0  Action|Adventure|Fantasy|Sci-Fi      CCH Pounder
# 1         Action|Adventure|Fantasy      Johnny Depp
# 2        Action|Adventure|Thriller  Christoph Waltz
# 3                  Action|Thriller        Tom Hardy
# 4                      Documentary      Doug Walker
#
#                                          movie_title  num_voted_users  \
# 0                                            Avatar            886204
# 1          Pirates of the Caribbean: At World's End            471220
# 2                                           Spectre            275868
# 3                             The Dark Knight Rises           1144337
# 4  Star Wars: Episode VII - The Force Awakens    ...                8
#
#                                        plot_keywords  num_user_for_reviews  \
# 0             avatar|future|marine|native|paraplegic                3054.0
# 1  goddess|marriage ceremony|marriage proposal|pi...                1238.0
# 2                bomb|espionage|sequel|spy|terrorist                 994.0
# 3  deception|imprisonment|lawlessness|police offi...                2701.0
# 4                                                NaN                   NaN
#
#   language       budget  title_year  imdb_score  movie_facebook_likes
# 0  English  237000000.0      2009.0         7.9                 33000
# 1  English  300000000.0      2007.0         7.1                     0
# 2  English  245000000.0      2015.0         6.8                 85000
# 3  English  250000000.0      2012.0         8.5                164000
# 4      NaN          NaN         NaN         7.1                     0

# %% [markdown]
# -  ### Subtask 2.3: Drop unecessary rows using columns with high Null percentages
#
# Now, on inspection you might notice that some columns have large percentage (greater than 5%) of Null values. Drop all the rows which have Null values for such columns.

# %%
# Write your code for dropping the rows here
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-65-6b91887602b5> in <module>()
#       2
#       3
# ----> 4 movies.isnull('True')
#
# TypeError: isnull() takes 1 positional argument but 2 were given

# %% [markdown]
# -  ### Subtask 2.4: Drop unecessary rows
#
# Some of the rows might have greater than five NaN values. Such rows aren't of much use for the analysis and hence, should be removed.

# %%
# Write your code for dropping the rows here

#Dropping rows with more than 5 NaN values. thresh is kept 5.
if (movies.isna()>5):
    then del

# %% [markdown]
# -  ### Subtask 2.5: Fill NaN values
#
# You might notice that the `language` column has some NaN values. Here, on inspection, you will see that it is safe to replace all the missing values with `'English'`.

# %%
# Write your code for filling the NaN values in the 'language' column here
movies['language']= 'English'
movies.head()
# Out:
#        director_name  num_critic_for_reviews        gross  \
# 0      James Cameron                   723.0  760505847.0
# 1     Gore Verbinski                   302.0  309404152.0
# 2         Sam Mendes                   602.0  200074175.0
# 3  Christopher Nolan                   813.0  448130642.0
# 4        Doug Walker                     NaN          NaN
#
#                             genres     actor_1_name  \
# 0  Action|Adventure|Fantasy|Sci-Fi      CCH Pounder
# 1         Action|Adventure|Fantasy      Johnny Depp
# 2        Action|Adventure|Thriller  Christoph Waltz
# 3                  Action|Thriller        Tom Hardy
# 4                      Documentary      Doug Walker
#
#                                          movie_title  num_voted_users  \
# 0                                            Avatar            886204
# 1          Pirates of the Caribbean: At World's End            471220
# 2                                           Spectre            275868
# 3                             The Dark Knight Rises           1144337
# 4  Star Wars: Episode VII - The Force Awakens    ...                8
#
#                                        plot_keywords  num_user_for_reviews  \
# 0             avatar|future|marine|native|paraplegic                3054.0
# 1  goddess|marriage ceremony|marriage proposal|pi...                1238.0
# 2                bomb|espionage|sequel|spy|terrorist                 994.0
# 3  deception|imprisonment|lawlessness|police offi...                2701.0
# 4                                                NaN                   NaN
#
#   language       budget  title_year  imdb_score  movie_facebook_likes
# 0  English  237000000.0      2009.0         7.9                 33000
# 1  English  300000000.0      2007.0         7.1                     0
# 2  English  245000000.0      2015.0         6.8                 85000
# 3  English  250000000.0      2012.0         8.5                164000
# 4  English          NaN         NaN         7.1                     0

# %% [markdown]
# -  ### Subtask 2.6: Check the number of retained rows
#
# You might notice that two of the columns viz. `num_critic_for_reviews` and `actor_1_name` have small percentages of NaN values left. You can let these columns as it is for now. Check the number and percentage of the rows retained after completing all the tasks above.

# %%
# Write your code for checking number of retained rows here
#[Your Code]
null_number=movies.loc[[4]].isna().sum()
null_perecnt=movies.loc[[4]].isna().sum().sum()/6*100
print(null_number, null_percent)
# Out:
# director_name             0
# num_critic_for_reviews    1
# gross                     1
# genres                    0
# actor_1_name              0
# movie_title               0
# num_voted_users           0
# plot_keywords             1
# num_user_for_reviews      1
# language                  0
# budget                    1
# title_year                1
# imdb_score                0
# movie_facebook_likes      0
# dtype: int64 36.307753321435655

# %% [markdown]
# **Checkpoint 1:** You might have noticed that we still have around `77%` of the rows!

# %% [markdown]
# ## Task 3: Data Analysis
#
# -  ### Subtask 3.1: Change the unit of columns
#
# Convert the unit of the `budget` and `gross` columns from `$` to `million $`.

# %%
# Write your code for unit conversion here
 
#Changing the value of each value of budget and gross by dividing by 1000000 using apply function.
#[Your Code]
movies.head()
# Out:
#        director_name  num_critic_for_reviews        gross  \
# 0      James Cameron                   723.0  760505847.0
# 1     Gore Verbinski                   302.0  309404152.0
# 2         Sam Mendes                   602.0  200074175.0
# 3  Christopher Nolan                   813.0  448130642.0
# 4        Doug Walker                     NaN          NaN
#
#                             genres     actor_1_name  \
# 0  Action|Adventure|Fantasy|Sci-Fi      CCH Pounder
# 1         Action|Adventure|Fantasy      Johnny Depp
# 2        Action|Adventure|Thriller  Christoph Waltz
# 3                  Action|Thriller        Tom Hardy
# 4                      Documentary      Doug Walker
#
#                                          movie_title  num_voted_users  \
# 0                                            Avatar            886204
# 1          Pirates of the Caribbean: At World's End            471220
# 2                                           Spectre            275868
# 3                             The Dark Knight Rises           1144337
# 4  Star Wars: Episode VII - The Force Awakens    ...                8
#
#                                        plot_keywords  num_user_for_reviews  \
# 0             avatar|future|marine|native|paraplegic                3054.0
# 1  goddess|marriage ceremony|marriage proposal|pi...                1238.0
# 2                bomb|espionage|sequel|spy|terrorist                 994.0
# 3  deception|imprisonment|lawlessness|police offi...                2701.0
# 4                                                NaN                   NaN
#
#   language       budget  title_year  imdb_score  movie_facebook_likes  \
# 0  English  237000000.0      2009.0         7.9                 33000
# 1  English  300000000.0      2007.0         7.1                     0
# 2  English  245000000.0      2015.0         6.8                 85000
# 3  English  250000000.0      2012.0         8.5                164000
# 4  English          NaN         NaN         7.1                     0
#
#         profit
# 0  523505847.0
# 1    9404152.0
# 2  -44925825.0
# 3  198130642.0
# 4          NaN

# %% [markdown]
# -  ### Subtask 3.2: Find the movies with highest profit
#
#     1. Create a new column called `profit` which contains the difference of the two columns: `gross` and `budget`.
#     2. Sort the dataframe using the `profit` column as reference.
#     3. Extract the top ten profiting movies in descending order and store them in a new dataframe - `top10`

# %%
# Write your code for creating the profit column here
movies['profit']=(movies['gross']-movies['budget'])
movies.head()
# Out:
#        director_name  num_critic_for_reviews        gross  \
# 0      James Cameron                   723.0  760505847.0
# 1     Gore Verbinski                   302.0  309404152.0
# 2         Sam Mendes                   602.0  200074175.0
# 3  Christopher Nolan                   813.0  448130642.0
# 4        Doug Walker                     NaN          NaN
#
#                             genres     actor_1_name  \
# 0  Action|Adventure|Fantasy|Sci-Fi      CCH Pounder
# 1         Action|Adventure|Fantasy      Johnny Depp
# 2        Action|Adventure|Thriller  Christoph Waltz
# 3                  Action|Thriller        Tom Hardy
# 4                      Documentary      Doug Walker
#
#                                          movie_title  num_voted_users  \
# 0                                            Avatar            886204
# 1          Pirates of the Caribbean: At World's End            471220
# 2                                           Spectre            275868
# 3                             The Dark Knight Rises           1144337
# 4  Star Wars: Episode VII - The Force Awakens    ...                8
#
#                                        plot_keywords  num_user_for_reviews  \
# 0             avatar|future|marine|native|paraplegic                3054.0
# 1  goddess|marriage ceremony|marriage proposal|pi...                1238.0
# 2                bomb|espionage|sequel|spy|terrorist                 994.0
# 3  deception|imprisonment|lawlessness|police offi...                2701.0
# 4                                                NaN                   NaN
#
#   language       budget  title_year  imdb_score  movie_facebook_likes  \
# 0  English  237000000.0      2009.0         7.9                 33000
# 1  English  300000000.0      2007.0         7.1                     0
# 2  English  245000000.0      2015.0         6.8                 85000
# 3  English  250000000.0      2012.0         8.5                164000
# 4  English          NaN         NaN         7.1                     0
#
#         profit
# 0  523505847.0
# 1    9404152.0
# 2  -44925825.0
# 3  198130642.0
# 4          NaN

# %%
# Write your code for sorting the dataframe here
movies.sort_values(by='profit', ascending=False)
# Out:
#            director_name  num_critic_for_reviews        gross  \
# 0          James Cameron                   723.0  760505847.0
# 29       Colin Trevorrow                   644.0  652177271.0
# 26         James Cameron                   315.0  658672302.0
# 3024        George Lucas                   282.0  460935665.0
# 3080    Steven Spielberg                   215.0  434949459.0
# 794          Joss Whedon                   703.0  623279547.0
# 17           Joss Whedon                   703.0  623279547.0
# 509         Roger Allers                   186.0  422783777.0
# 240         George Lucas                   320.0  474544677.0
# 66     Christopher Nolan                   645.0  533316061.0
# 439            Gary Ross                   673.0  407999255.0
# 812           Tim Miller                   579.0  363024263.0
# 186     Francis Lawrence                   502.0  424645577.0
# 697     Steven Spielberg                   308.0  356784000.0
# 521        Pierre Coffin                   306.0  368049635.0
# 814       Clint Eastwood                   490.0  350123553.0
# 338       Andrew Stanton                   301.0  380838870.0
# 582       Andrew Adamson                   205.0  436471036.0
# 339        Peter Jackson                   328.0  377019252.0
# 1536    Richard Marquand                   197.0  309125409.0
# 836      Robert Zemeckis                   149.0  329691196.0
# 2051      Irvin Kershner                   223.0  290158751.0
# 2601      Chris Columbus                   102.0  285761243.0
# 236         George Lucas                   359.0  380262555.0
# 161            Sam Raimi                   291.0  403706375.0
# 563           Kyle Balda                   308.0  336029560.0
# 1181  M. Night Shyamalan                   234.0  293501675.0
# 2917    Steven Spielberg                   385.0  260000000.0
# 125           Chris Buck                   406.0  400736600.0
# 519        Yarrow Cheney                   165.0  323505540.0
# ...                  ...                     ...          ...
# 4994      Patrick Meaney                     7.0          NaN
# 4995       Chad Hartigan                    34.0          NaN
# 4996     Malcolm Goodwin                     NaN          NaN
# 4999         Kirk Loudon                     3.0          NaN
# 5000        Travis Legge                     2.0          NaN
# 5001     Martin Scorsese                    71.0     321952.0
# 5002  Collin Joseph Neal                     7.0          NaN
# 5003   Bradley Rust Gray                    61.0      24705.0
# 5005     Andrew Bujalski                    52.0          NaN
# 5006         Damir Catic                     NaN          NaN
# 5007        Ben Wheatley                    53.0       9609.0
# 5010     Andrew Bujalski                    43.0          NaN
# 5013          Eric Eason                    28.0          NaN
# 5014            Uwe Boll                    58.0          NaN
# 5016     Joseph Mazzella                     NaN          NaN
# 5017        Travis Legge                     1.0          NaN
# 5018       Alex Kendrick                     5.0          NaN
# 5019       Marcus Nispel                    43.0          NaN
# 5020     Brandon Landers                     NaN          NaN
# 5022          Jim Chuchu                     6.0          NaN
# 5024         Jason Trost                    42.0          NaN
# 5028       Ivan Kavanagh                    12.0          NaN
# 5030        Tadeo Garcia                     NaN          NaN
# 5031  Thomas L. Phillips                    13.0          NaN
# 5032     Ash Baron-Cohen                    10.0          NaN
# 5036     Anthony Vallone                     NaN          NaN
# 5038         Scott Smith                     1.0          NaN
# 5039                 NaN                    43.0          NaN
# 5040    Benjamin Roberds                    13.0          NaN
# 5041         Daniel Hsia                    14.0      10443.0
#
#                                                  genres         actor_1_name  \
# 0                       Action|Adventure|Fantasy|Sci-Fi          CCH Pounder
# 29                     Action|Adventure|Sci-Fi|Thriller  Bryce Dallas Howard
# 26                                        Drama|Romance    Leonardo DiCaprio
# 3024                    Action|Adventure|Fantasy|Sci-Fi        Harrison Ford
# 3080                                      Family|Sci-Fi         Henry Thomas
# 794                             Action|Adventure|Sci-Fi      Chris Hemsworth
# 17                              Action|Adventure|Sci-Fi      Chris Hemsworth
# 509            Adventure|Animation|Drama|Family|Musical    Matthew Broderick
# 240                     Action|Adventure|Fantasy|Sci-Fi      Natalie Portman
# 66                          Action|Crime|Drama|Thriller       Christian Bale
# 439                     Adventure|Drama|Sci-Fi|Thriller    Jennifer Lawrence
# 812              Action|Adventure|Comedy|Romance|Sci-Fi        Ryan Reynolds
# 186                           Adventure|Sci-Fi|Thriller    Jennifer Lawrence
# 697                           Adventure|Sci-Fi|Thriller         Wayne Knight
# 521                      Animation|Comedy|Family|Sci-Fi         Steve Carell
# 814         Action|Biography|Drama|History|Thriller|War       Bradley Cooper
# 338                   Adventure|Animation|Comedy|Family      Alexander Gould
# 582   Adventure|Animation|Comedy|Family|Fantasy|Romance       Rupert Everett
# 339                      Action|Adventure|Drama|Fantasy        Orlando Bloom
# 1536                    Action|Adventure|Fantasy|Sci-Fi        Harrison Ford
# 836                                        Comedy|Drama            Tom Hanks
# 2051                    Action|Adventure|Fantasy|Sci-Fi        Harrison Ford
# 2601                                      Comedy|Family      Macaulay Culkin
# 236                     Action|Adventure|Fantasy|Sci-Fi      Natalie Portman
# 161                    Action|Adventure|Fantasy|Romance         J.K. Simmons
# 563               Action|Animation|Comedy|Family|Sci-Fi         Steve Carell
# 1181                             Drama|Mystery|Thriller         Bruce Willis
# 2917                           Adventure|Drama|Thriller         Roy Scheider
# 125   Adventure|Animation|Comedy|Family|Fantasy|Musical             Josh Gad
# 519                             Animation|Comedy|Family         Steve Coogan
# ...                                                 ...                  ...
# 4994                              Biography|Documentary       Taliesin Jaffe
# 4995                                              Drama            Jan Haley
# 4996                                             Comedy       Katrina Bowden
# 4999                              Drama|Sci-Fi|Thriller         Barry Corbin
# 5000                                             Horror       Elissa Dowling
# 5001                                  Documentary|Music          Ringo Starr
# 5002                                    Horror|Thriller      Julianne Gabert
# 5003                                              Drama            Zoe Kazan
# 5005                                             Comedy      Andrew Bujalski
# 5006                                             Horror     Nichole Ceballos
# 5007                                 Comedy|Crime|Drama       Michael Smiley
# 5010                                       Comedy|Drama      Andrew Bujalski
# 5013                                       Drama|Family             Franky G
# 5014                              Action|Crime|Thriller          Matt Frewer
# 5016                               Crime|Drama|Thriller          Tjasa Ferme
# 5017                                     Comedy|Romance       Kristen Seavey
# 5018                                              Drama       Shannen Fields
# 5019                            Horror|Mystery|Thriller      Ashley Tramonte
# 5020                              Drama|Horror|Thriller        Robbie Barnes
# 5022                                              Drama           Paul Ogola
# 5024                                    Sci-Fi|Thriller          Sean Whalen
# 5028                                             Horror    Patrick O'Donnell
# 5030                                              Drama  Tatiana Suarez-Pico
# 5031                             Comedy|Horror|Thriller        Julianna Pitt
# 5032                                        Crime|Drama         Peter Greene
# 5036                                        Crime|Drama       Richard Jewell
# 5038                                       Comedy|Drama          Eric Mabius
# 5039                       Crime|Drama|Mystery|Thriller          Natalie Zea
# 5040                              Drama|Horror|Thriller          Eva Boehnke
# 5041                               Comedy|Drama|Romance            Alan Ruck
#
#                                           movie_title  num_voted_users  \
# 0                                             Avatar            886204
# 5017          NaN
# 5018          NaN
# 5019          NaN
# 5020          NaN
# 5022          NaN
# 5024          NaN
# 5028          NaN
# 5030          NaN
# 5031          NaN
# 5032          NaN
# 5036          NaN
# 5038          NaN
# 5039          NaN
# 5040          NaN
# 5041          NaN
#
# [5043 rows x 15 columns]

# %%
data= movies.sort_values(by='profit', ascending=False)
top10= pd.DataFrame(data, columns=['profit'])
top10.head(10)
# Out:
#            profit
# 0     523505847.0
# 29    502177271.0
# 26    458672302.0
# 3024  449935665.0
# 3080  424449459.0
# 794   403279547.0
# 17    403279547.0
# 509   377783777.0
# 240   359544677.0
# 66    348316061.0

# %% [markdown]
# -  ### Subtask 3.3: Drop duplicate values
#
# After you found out the top 10 profiting movies, you might have notice a duplicate value. So, it seems like the dataframe has duplicate values as well. Drop the duplicate values from the dataframe and repeat `Subtask 3.2`.

# %%
# Write your code for dropping duplicate values here
top10.drop_duplicates(subset=None,keep='first',inplace=False).head(10)
# Out:
#            profit
# 0     523505847.0
# 29    502177271.0
# 26    458672302.0
# 3024  449935665.0
# 3080  424449459.0
# 794   403279547.0
# 509   377783777.0
# 240   359544677.0
# 66    348316061.0
# 439   329999255.0

# %%
# Write code for repeating subtask 2 here

#Sort df by profit in descending order.Print Top 10 movies for verification.
data= movies.sort_values(by='profit', ascending=False)
top10= pd.DataFrame(data, columns=['profit'])
top10.head(10)
# Out:
#            profit
# 0     523505847.0
# 29    502177271.0
# 26    458672302.0
# 3024  449935665.0
# 3080  424449459.0
# 794   403279547.0
# 17    403279547.0
# 509   377783777.0
# 240   359544677.0
# 66    348316061.0

# %% [markdown]
# **Checkpoint 2:** You might spot two movies directed by `James Cameron` in the list.

# %% [markdown]
# -  ### Subtask 3.4: Find IMDb Top 250
#
#     1. Create a new dataframe `IMDb_Top_250` and store the top 250 movies with the highest IMDb Rating (corresponding to the column: `imdb_score`). Also make sure that for all of these movies, the `num_voted_users` is greater than 25,000.
# Also add a `Rank` column containing the values 1 to 250 indicating the ranks of the corresponding films.
#     2. Extract all the movies in the `IMDb_Top_250` dataframe which are not in the English language and store them in a new dataframe named `Top_Foreign_Lang_Film`.

# %%
# Write your code for extracting the top 250 movies as per the IMDb score here. Make sure that you store it in a new dataframe 
# and name that dataframe as 'IMDb_Top_250'
data= movies.sort_values(by='imdb_score', ascending=False)
IMDB_Top_250= pd.DataFrame(data, columns=['movie_title','imdb_score'])
IMDB_Top_250.head(250)
# Out:
#                                             movie_title  imdb_score
# 2765                      Towering Inferno                      9.5
# 1937                          The Shawshank Redemption          9.3
# 3466                                     The Godfather          9.2
# 4409                              Kickboxer: Vengeance          9.1
# 2824                               Dekalog                      9.1
# 3207                               Dekalog                      9.1
# 66                                     The Dark Knight          9.0
# 2837                            The Godfather: Part II          9.0
# 3481                                 Fargo                      9.0
# 339      The Lord of the Rings: The Return of the King          8.9
# 4822                                      12 Angry Men          8.9
# 4498                    The Good, the Bad and the Ugly          8.9
# 3355                                      Pulp Fiction          8.9
# 1874                                  Schindler's List          8.9
# 683                                         Fight Club          8.8
# 836                                       Forrest Gump          8.8
# 270   The Lord of the Rings: The Fellowship of the R...         8.8
# 2051    Star Wars: Episode V - The Empire Strikes Back          8.8
# 97                                           Inception          8.8
# 1842     It's Always Sunny in Philadelphia                      8.8
# 459                              Daredevil                      8.8
# 1620                   Friday Night Lights                      8.7
# 1818                      The Honeymooners                      8.7
# 654                                         The Matrix          8.7
# 4468                            Queen of the Mountains          8.7
# 3867                   One Flew Over the Cuckoo's Nest          8.7
# 340              The Lord of the Rings: The Two Towers          8.7
# 3024                Star Wars: Episode IV - A New Hope          8.7
# 4747                                     Seven Samurai          8.7
# 4924                                    Butterfly Girl          8.7
# ...                                                 ...         ...
# 3362                                       Stand by Me          8.1
# 4912                                             Ordet          8.1
# 1911                               There Will Be Blood          8.1
# 4061                             Cat on a Hot Tin Roof          8.1
# 2870         Del 1 - Män som hatar kvinnor                      8.1
# 128                                 Mad Max: Fury Road          8.1
# 4041                  The Man Who Shot Liberty Valance          8.1
# 855                                  Kill Bill: Vol. 1          8.1
# 4034                                 A Christmas Story          8.1
# 3969                                           Network          8.1
# 2755                                     Groundhog Day          8.1
# 1373                                              Rush          8.1
# 3423                                             Akira          8.1
# 1875                                          The Help          8.1
# 95                             Guardians of the Galaxy          8.1
# 1885                            No Country for Old Men          8.1
# 4190                                    Before Sunrise          8.1
# 794                                       The Avengers          8.1
# 3553                                       Elite Squad          8.1
# 183                               The Bourne Ultimatum          8.1
# 205   Pirates of the Caribbean: The Curse of the Bla...         8.1
# 3881                        Animal Kingdom                      8.1
# 2914                Tae Guk Gi: The Brotherhood of War          8.1
# 697                                      Jurassic Park          8.1
# 3889                                        Annie Hall          8.1
# 17                                        The Avengers          8.1
# 2174                                  12 Years a Slave          8.1
# 715                                          Gone Girl          8.1
# 4238                       The Best Years of Our Lives          8.1
# 719                                    The Truman Show          8.1
#
# [250 rows x 2 columns]

# %%
#Taking rows whoes language column value is not En
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-113-66aaddb11a29> in <module>()
#       1 #Taking rows whoes language column value is not English.
# ----> 2 clear
#
# NameError: name 'clear' is not defined

# %% [markdown]
# **Checkpoint 3:** Can you spot `Veer-Zaara` in the dataframe?

# %% [markdown]
# - ### Subtask 3.5: Find the best directors
#
#     1. Group the dataframe using the `director_name` column.
#     2. Find out the top 10 directors for whom the mean of `imdb_score` is the highest and store them in a new dataframe `top10director`.

# %%
#Write your code for extracting the top 10 directors here
movies['mean_imdb_score']=movies['imdb_score'].mean()
data= movies.sort_values(by='mean_imdb_score', ascending=False)
top10director= pd.DataFrame(data, columns=['director_name','imdb_score','mean_imdb_score'])
top10director.head(10)
# Out:
#           director_name  imdb_score  mean_imdb_score
# 0         James Cameron         7.9         6.442138
# 3359        Robert Wise         8.0         6.442138
# 3366      Rick Famuyiwa         6.5         6.442138
# 3365         Don Siegel         7.6         6.442138
# 3364       Chris Stokes         3.5         6.442138
# 3363        Danny Boyle         7.6         6.442138
# 3362         Rob Reiner         8.1         6.442138
# 3361    Jonathan Dayton         7.9         6.442138
# 3360         Ron Howard         6.2         6.442138
# 3358  Jay Chandrasekhar         5.6         6.442138

# %% [markdown]
# **Checkpoint 4:** No surprises that `Damien Chazelle` (director of Whiplash and La La Land) is in this list.

# %% [markdown]
# -  ### Subtask 3.6: Find popular genres
#
# You might have noticed the `genres` column in the dataframe with all the genres of the movies seperated by a pipe (`|`). Out of all the movie genres, the first two are most significant for any film.
#
# 1. Extract the first two genres from the `genres` column and store them in two new columns: `genre_1` and `genre_2`. Some of the movies might have only one genre. In such cases, extract the single genre into both the columns, i.e. for such movies the `genre_2` will be the same as `genre_1`.
# 2. Group the dataframe using `genre_1` as the primary column and `genre_2` as the secondary column.
# 3. Find out the 5 most popular combo of genres by finding the mean of the gross values using the `gross` column and store them in a new dataframe named `PopGenre`.

# %%
# Write your code for extracting the first two genres of each movie here
#[Your Code]
movies['mean_imdb_score']=movies['imdb_score'].mean()
movies.head()
# Out:
#        director_name  num_critic_for_reviews        gross  \
# 0      James Cameron                   723.0  760505847.0
# 1     Gore Verbinski                   302.0  309404152.0
# 2         Sam Mendes                   602.0  200074175.0
# 3  Christopher Nolan                   813.0  448130642.0
# 4        Doug Walker                     NaN          NaN
#
#                             genres     actor_1_name  \
# 0  Action|Adventure|Fantasy|Sci-Fi      CCH Pounder
# 1         Action|Adventure|Fantasy      Johnny Depp
# 2        Action|Adventure|Thriller  Christoph Waltz
# 3                  Action|Thriller        Tom Hardy
# 4                      Documentary      Doug Walker
#
#                                          movie_title  num_voted_users  \
# 0                                            Avatar            886204
# 1          Pirates of the Caribbean: At World's End            471220
# 2                                           Spectre            275868
# 3                             The Dark Knight Rises           1144337
# 4  Star Wars: Episode VII - The Force Awakens    ...                8
#
#                                        plot_keywords  num_user_for_reviews  \
# 0             avatar|future|marine|native|paraplegic                3054.0
# 1  goddess|marriage ceremony|marriage proposal|pi...                1238.0
# 2                bomb|espionage|sequel|spy|terrorist                 994.0
# 3  deception|imprisonment|lawlessness|police offi...                2701.0
# 4                                                NaN                   NaN
#
#   language       budget  title_year  imdb_score  movie_facebook_likes  \
# 0  English  237000000.0      2009.0         7.9                 33000
# 1  English  300000000.0      2007.0         7.1                     0
# 2  English  245000000.0      2015.0         6.8                 85000
# 3  English  250000000.0      2012.0         8.5                164000
# 4  English          NaN         NaN         7.1                     0
#
#         profit  mean_imdb_score
# 0  523505847.0         6.442138
# 1    9404152.0         6.442138
# 2  -44925825.0         6.442138
# 3  198130642.0         6.442138
# 4          NaN         6.442138

# %%
#Movies has been grouped by genre_1 and then genre_2

# %%
#Pivot table can be used to calculate the mean gross and then group by genres. And then sorted by the gross value.

# %% [markdown]
# **Checkpoint 5:** Well, as it turns out. `Family + Sci-Fi` is the most popular combo of genres out there!

# %% [markdown]
# -  ### Subtask 3.7: Find the critic-favorite and audience-favorite actors
#
#     1. Create three new dataframes namely, `Meryl_Streep`, `Leo_Caprio`, and `Brad_Pitt` which contain the movies in which the actors: 'Meryl Streep', 'Leonardo DiCaprio', and 'Brad Pitt' are the lead actors. Use only the `actor_1_name` column for extraction. Also, make sure that you use the names 'Meryl Streep', 'Leonardo DiCaprio', and 'Brad Pitt' for the said extraction.
#     2. Append the rows of all these dataframes and store them in a new dataframe named `Combined`.
#     3. Group the combined dataframe using the `actor_1_name` column.
#     4. Find the mean of the `num_critic_for_reviews` and `num_user_for_review` and identify the actors which have the highest mean.

# %%
# Write your code for creating three new dataframes here

# %%
#Using loc function to check if the actor name contains Leonardo DiCaprio, including only those rows.

# %%
#Using loc function to check if the actor name contains Brad Pitt, including only those rows.
#[Your Code]

# %%
# Write your code for combining the three dataframes here

# %%
# Write your code for grouping the combined dataframe here

# %%
#Mean critic Review and Mean audience review grouped by the actor's name in above combined data frame
#Using pivot to grorup by both and then get sorted mean.

# %% [markdown]
# **Checkpoint 6:** `Leonardo` has aced both the lists!
